# %%
#Bibliotecas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys

sns.set()  

###Função
#Gráficos
def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).unstack().plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

#Definir mês
def printMonth(num):
    if num == 1:
        month =' JAN'
    elif num == 2:
        month = 'FEV'
    elif num == 3:
        month = 'MAR'
    elif num == 4:
        month= 'APR'
    elif num == 5:
        month= 'MAY'
    elif num == 6:
        month = 'JUN'
    elif num == 7:
        month = 'JUL'
    elif num == 8:
        month = 'AUG'
    elif num == 9:
        month= 'SEP'
    elif num == 10:
        month= 'OCT'
    elif num == 11:
        month= 'NOV'
    elif num == 12:
        month= 'DEC'
    return month


###Inicio
#Buscando ano e mês para montar nome do arquivo
ano = input ('Digite ano desejado no formato YYYY: ')
mes_aux = int(input ('Digite mês desejado no formato MM: '))
mes = printMonth(mes_aux)
nome_arq = 'SINASC_RO_' + ano + '_' + mes +'.csv'

#Lendo arquivo
sinasc = pd.read_csv(nome_arq)

#Mostrando data do arquivo
max_data = sinasc.DTNASC.max()[:7]
print(max_data)

#Criando diretório
os.makedirs('./output/figs/'+max_data, exist_ok=True)

#Rodando os gráficos
plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'mean', 'média idade mãe por data', 'data nascimento')
plt.savefig('./output/figs/'+max_data+'/media idade mae por data.png')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'mean', 'media idade mae','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo.png')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'mean', 'media peso bebe','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media peso bebe por sexo.png')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'PESO mediano','escolaridade mae','sort')
plt.savefig('./output/figs/'+max_data+'/PESO mediano por escolaridade mae.png')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')
# Out:
# Digite ano desejado no formato YYYY: 2019
# Digite mês desejado no formato MM: 12
# 2019-12

# %% [markdown]
# ### Como otimizar mai ainda o gráfico

# %% [markdown]
# - Existe algumas formas de otimizar o script de criação de gráficos, abaixo segue 2 que me veio na mente:
#     1) Utilizando o código que implementei para perguntar ano e mês desejado;
#     2) Gerando o Arquivo de entrada sempre com o mesmo nome e no mesmo diretório;
